# %% [markdown]
# <a href="https://colab.research.google.com/github/Kenethoriga/secondhand-textile-demand-forecasting/blob/main/LSTM_FinalBest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Dataset
data = {
    "Year": list(range(2000, 2024)),
    "Inflation (%)": [9.98, 5.74, 1.96, 9.82, 11.62, 10.31, 14.49, 9.8, 26.2, 10.3, 4.11, 14.0, 9.38, 5.72, 6.91, 6.58, 6.3, 4.69, 5.19, 5.4, 6.1, 6.5, 7.2, 6.9],
    "Imports (tons)": [18913, 19389, 19261, 25440, 26938, 23967, 23961, 22545, 17645, 16594, 16628, 18182, 19451, 18183, 20051, 21459, 21452, 20124, 24145, 24344, 26867, 29867, 28847, 27309],
    "Cost (Ksh/ton)": [93600, 101400, 109204, 118500, 120000, 124000, 137211, 114332, 149002, 150583, 234742, 280124, 258337, 280434, 288865, 308640, 296718, 267671, 271251, 270477, 245025, 272660, 292978, 305062],
    "Textile Waste (tons)": [4200, 4800, 5100, 6900, 7200, 6000, 5500, 6300, 5800, 4500, 5200, 6700, 7500, 6200, 6800, 7000, 6500, 5900, 8200, 7600, 9300, 8700, 9100, 8400],
    "Avg. Temp (°C)": [21.9, 22.1, 21.7, 21.4, 21.8, 22.3, 22, 21.5, 21.9, 22.6, 21.7, 22.2, 21.4, 22.5, 21.8, 22, 21.3, 22.7, 21.6, 21.9, 21.2, 22.4, 21.5, 22.1],
    "Annual Rainfall (mm)": [278.01, 767.26, 729.67, 613.8, 693.04, 397.73, 717.6, 473.89, 453.68, 408.56, 687.62, 582.9, 810.73, 798.64, 536.07, 801.42, 538.27, 352.55, 1043.19, 937.54, 1107.96, 610.92, 403.99, 448.47],
    "Key Event": [
        "Limited recycling infrastructure", "Drought reduces waste dumping", "Introduction of first landfill regulations",
        "Severe floods wash textiles into rivers", "Dandora landfill experiences significant overflows",
        "UNEP launches anti-dumping campaign", "Ban on textile burning implemented",
        "Community-led Kibera cleanup initiative launched", "Global economic crisis reduces consumption and waste generation",
        "Economic downturn results in lower textile waste", "Market flooded with cheaper synthetics from abroad",
        "Mitumba trade becomes formalized", "Dandora landfill officially declared hazardous",
        "Emergence of upcycling startups boosts textile recovery", "Africa Collect Textiles organization established",
        "National Waste Management Act passed", "Temporary EU export ban impacts supply dynamics",
        "Heightened concerns as pollution in Nairobi River peaks",
        "Acute waste management crisis in Kantamanto district emerges",
        "Disruptions in waste disposal due to COVID-19 measures",
        "Surge in PPE waste complicates textile waste management",
        "Post-COVID, a significant push towards enhanced recycling initiatives",
        "Expansion of Takataka Solutions improves recycling capabilities",
        "Renewed river cleanup initiative with community and technological support"
    ]
}
df = pd.DataFrame(data)
df
# Out:
#     Year  Inflation (%)  Imports (tons)  Cost (Ksh/ton)  Textile Waste (tons)  \
# 0   2000           9.98           18913           93600                  4200
# 1   2001           5.74           19389          101400                  4800
# 2   2002           1.96           19261          109204                  5100
# 3   2003           9.82           25440          118500                  6900
# 4   2004          11.62           26938          120000                  7200
# 5   2005          10.31           23967          124000                  6000
# 6   2006          14.49           23961          137211                  5500
# 7   2007           9.80           22545          114332                  6300
# 8   2008          26.20           17645          149002                  5800
# 9   2009          10.30           16594          150583                  4500
# 10  2010           4.11           16628          234742                  5200
# 11  2011          14.00           18182          280124                  6700
# 12  2012           9.38           19451          258337                  7500
# 13  2013           5.72           18183          280434                  6200
# 14  2014           6.91           20051          288865                  6800
# 15  2015           6.58           21459          308640                  7000
# 16  2016           6.30           21452          296718                  6500
# 17  2017           4.69           20124          267671                  5900
# 18  2018           5.19           24145          271251                  8200
# 19  2019           5.40           24344          270477                  7600
# 20  2020           6.10           26867          245025                  9300
# 21  2021           6.50           29867          272660                  8700
# 22  2022           7.20           28847          292978                  9100
# 23  2023           6.90           27309          305062                  8400
#
#     Avg. Temp (°C)  Annual Rainfall (mm)  \
# 0             21.9                278.01
# 1             22.1                767.26
# 2             21.7                729.67
# 3             21.4                613.80
# 4             21.8                693.04
# 5             22.3                397.73
# 6             22.0                717.60
# 7             21.5                473.89
# 8             21.9                453.68
# 9             22.6                408.56
# 10            21.7                687.62
# 11            22.2                582.90
# 12            21.4                810.73
# 13            22.5                798.64
# 14            21.8                536.07
# 15            22.0                801.42
# 16            21.3                538.27
# 17            22.7                352.55
# 18            21.6               1043.19
# 19            21.9                937.54
# 20            21.2               1107.96
# 21            22.4                610.92
# 22            21.5                403.99
# 23            22.1                448.47
#
#                                             Key Event
# 0                    Limited recycling infrastructure
# 1                       Drought reduces waste dumping
# 2          Introduction of first landfill regulations
# 3             Severe floods wash textiles into rivers
# 4   Dandora landfill experiences significant overf...
# 5                 UNEP launches anti-dumping campaign
# 6                  Ban on textile burning implemented
# 7    Community-led Kibera cleanup initiative launched
# 8   Global economic crisis reduces consumption and...
# 9    Economic downturn results in lower textile waste
# 10  Market flooded with cheaper synthetics from ab...
# 11                   Mitumba trade becomes formalized
# 12     Dandora landfill officially declared hazardous
# 13  Emergence of upcycling startups boosts textile...
# 14   Africa Collect Textiles organization established
# 15               National Waste Management Act passed
# 16    Temporary EU export ban impacts supply dynamics
# 17  Heightened concerns as pollution in Nairobi Ri...
# 18  Acute waste management crisis in Kantamanto di...
# 19  Disruptions in waste disposal due to COVID-19 ...
# 20  Surge in PPE waste complicates textile waste m...
# 21  Post-COVID, a significant push towards enhance...
# 22  Expansion of Takataka Solutions improves recyc...
# 23  Renewed river cleanup initiative with communit...

# %%
# ------------------------------
# 2. Correlation Analysis
# ------------------------------
# Select numerical columns (exclude 'Year' and 'Key Event')
numerical_cols = ['Inflation (%)', 'Imports (tons)', 'Cost (Ksh/ton)', 'Textile Waste (tons)', 'Avg. Temp (°C)', 'Annual Rainfall (mm)']
corr_matrix = df[numerical_cols].corr()
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(
    corr_matrix,
    annot=True,      # Show correlation values
    cmap='coolwarm', # Color scheme (blue to red)
    fmt=".2f",       # Format to 2 decimal places
    linewidths=0.5,  # Add lines between cells
    vmin=-1,         # Minimum correlation value
    vmax=1           # Maximum correlation value
)

plt.title("Correlation Heatmap of Textile Import/Waste Factors (2000-2023)")
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.tight_layout()
plt.show()

# %%
# Encode Key Event
label_encoder = LabelEncoder()
df['Event_Encoded'] = label_encoder.fit_transform(df['Key Event'])

# Feature Scaling

features = ['Inflation (%)', 'Imports (tons)', 'Cost (Ksh/ton)', 'Avg. Temp (°C)', 'Annual Rainfall (mm)', 'Event_Encoded']
target_imports = ['Imports (tons)']
target_waste = ['Textile Waste (tons)']

scaler_X = MinMaxScaler()
scaler_y_imports = MinMaxScaler()
scaler_y_waste = MinMaxScaler()

X_scaled = scaler_X.fit_transform(df[features])
y_scaled_imports = scaler_y_imports.fit_transform(df[target_imports])
y_scaled_waste = scaler_y_waste.fit_transform(df[target_waste])

# %%
def create_sequences(X, y, window_size=3):
    X_seq, y_seq = [], []
    for i in range(len(X) - window_size):
        X_seq.append(X[i:i+window_size])
        y_seq.append(y[i+window_size])
    return np.array(X_seq), np.array(y_seq)

X_seq, y_seq_imports = create_sequences(X_scaled, y_scaled_imports, window_size=3)
_, y_seq_waste = create_sequences(X_scaled, y_scaled_waste, window_size=3)
# Print out shape and sample values
print("Shape of X_seq:", X_seq.shape)
print("Shape of y_seq_imports:", y_seq_imports.shape)
print("Shape of y_seq_waste:", y_seq_waste.shape)
# Out:
# Shape of X_seq: (21, 3, 6)
# Shape of y_seq_imports: (21, 1)
# Shape of y_seq_waste: (21, 1)

# %%
def build_model():
    model = Sequential()
    model.add(LSTM(64, activation='tanh', return_sequences=True, input_shape=(X_seq.shape[1], X_seq.shape[2])))
    model.add(LSTM(64, activation='tanh'))
    model.add(Dense(128))
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

def train_model(model, X_seq, y_seq, target_name):
    checkpoint_dir = f"checkpoints_{target_name}"
    os.makedirs(checkpoint_dir, exist_ok=True)
    checkpoint_path = os.path.join(checkpoint_dir, f"best_model_{target_name}.keras")
    checkpoint = ModelCheckpoint(filepath=checkpoint_path, monitor='loss', save_best_only=True, mode='min', verbose=1)
    early_stop = EarlyStopping(monitor='loss', patience=20, restore_best_weights=True)
    model.fit(X_seq, y_seq, epochs=200, batch_size=4, verbose=1, callbacks=[checkpoint, early_stop])
    return load_model(checkpoint_path)

model_imports = build_model()
best_model_imports = train_model(model_imports, X_seq, y_seq_imports, 'imports')

model_waste = build_model()
best_model_waste = train_model(model_waste, X_seq, y_seq_waste, 'waste')
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 19s 4s/step - loss: 0.2300
# Epoch 1: loss improved from inf to 0.20795, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1999
# Epoch 2/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1192
# Epoch 2: loss improved from 0.20795 to 0.08508, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0909
# Epoch 3/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0570
# Epoch 3: loss did not improve from 0.08508
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0904
# Epoch 4/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0467
# Epoch 4: loss improved from 0.08508 to 0.07870, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0706
# Epoch 5/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0830
# Epoch 5: loss did not improve from 0.07870
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0846
# Epoch 6/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1252
# Epoch 6: loss did not improve from 0.07870
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0915
# Epoch 7/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0687
# Epoch 7: loss improved from 0.07870 to 0.05938, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0573
# Epoch 8/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0646
# Epoch 8: loss improved from 0.05938 to 0.05596, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0559
# Epoch 9/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0526
# Epoch 9: loss improved from 0.05596 to 0.05398, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0488
# Epoch 10/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0657
# Epoch 10: loss improved from 0.05398 to 0.04691, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0563
# Epoch 11/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0471
# Epoch 11: loss did not improve from 0.04691
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0542
# Epoch 12/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0905
# Epoch 12: loss improved from 0.04691 to 0.03166, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0485
# Epoch 13/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0437
# Epoch 13: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0428
# Epoch 14/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0385
# Epoch 14: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0327
# Epoch 15/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0152
# Epoch 15: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0321
# Epoch 16/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0061
# Epoch 16: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0264
# Epoch 17/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0383
# Epoch 17: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0401
# Epoch 18/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0749
# Epoch 18: loss did not improve from 0.03166
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0413
# Epoch 19/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0194
# Epoch 19: loss improved from 0.03166 to 0.02389, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0195
# Epoch 20/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0203
# Epoch 20: loss did not improve from 0.02389
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0279
# Epoch 21/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0414
# Epoch 21: loss did not improve from 0.02389
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0323
# Epoch 22/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0285
# Epoch 22: loss improved from 0.02389 to 0.02114, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0251
# Epoch 23/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0355
# Epoch 23: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0273
# Epoch 24/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0252
# Epoch 24: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0260
# Epoch 25/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0244
# Epoch 25: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0193
# Epoch 26/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0478
# Epoch 26: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0298
# Epoch 27/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0100
# Epoch 27: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0286
# Epoch 28/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0145
# Epoch 28: loss did not improve from 0.02114
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0208
# Epoch 29/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0062
# Epoch 29: loss improved from 0.02114 to 0.02012, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0156
# Epoch 30/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0074
# Epoch 30: loss did not improve from 0.02012
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0221
# Epoch 31/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0231
# Epoch 31: loss improved from 0.02012 to 0.01539, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0178
# Epoch 32/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0314
# Epoch 32: loss did not improve from 0.01539
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0238
# Epoch 33/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0121
# Epoch 33: loss improved from 0.01539 to 0.01353, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0130
# Epoch 34/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0170
# Epoch 34: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0170
# Epoch 35/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0110
# Epoch 35: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0183
# Epoch 36/200
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0160
# Epoch 36: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0160
# Epoch 37/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0133
# Epoch 37: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0216
# Epoch 38/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0269
# Epoch 38: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0273
# Epoch 39/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0291
# Epoch 39: loss did not improve from 0.01353
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0196
# Epoch 40/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0177
# Epoch 40: loss improved from 0.01353 to 0.01199, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0126
# Epoch 41/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0164
# Epoch 41: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0158
# Epoch 42/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0172
# Epoch 42: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0192
# Epoch 43/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - loss: 0.0155
# Epoch 43: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0161
# Epoch 44/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0049
# Epoch 44: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0133
# Epoch 45/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0156
# Epoch 45: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0181
# Epoch 46/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0116
# Epoch 46: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0169
# Epoch 47/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0111
# Epoch 47: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0135
# Epoch 48/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0090
# Epoch 48: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119
# Epoch 49/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0132
# Epoch 49: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0180
# Epoch 50/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0110
# Epoch 50: loss did not improve from 0.01199
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184
# Epoch 51/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0095
# Epoch 51: loss improved from 0.01199 to 0.00947, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0097
# Epoch 52/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0164
# Epoch 52: loss did not improve from 0.00947
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0139
# Epoch 53/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0157
# Epoch 53: loss did not improve from 0.00947
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0150
# Epoch 54/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0195
# Epoch 54: loss did not improve from 0.00947
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0132
# Epoch 55/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0043
# Epoch 55: loss did not improve from 0.00947
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0089
# Epoch 56/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0076
# Epoch 56: loss improved from 0.00947 to 0.00832, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0088
# Epoch 57/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0172
# Epoch 57: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0149
# Epoch 58/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0157
# Epoch 58: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0124
# Epoch 59/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0125
# Epoch 59: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0099
# Epoch 60/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0168
# Epoch 60: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0149
# Epoch 61/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0081
# Epoch 61: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0082
# Epoch 62/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0248
# Epoch 62: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0148
# Epoch 63/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0121
# Epoch 63: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0113
# Epoch 64/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0239
# Epoch 64: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149
# Epoch 65/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0117
# Epoch 65: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104
# Epoch 66/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0152
# Epoch 66: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0109
# Epoch 67/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0122
# Epoch 67: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104
# Epoch 68/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0208
# Epoch 68: loss did not improve from 0.00832
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176
# Epoch 69/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0084
# Epoch 69: loss improved from 0.00832 to 0.00750, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0070
# Epoch 70/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 8.8658e-04
# Epoch 70: loss did not improve from 0.00750
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0094
# Epoch 71/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0166
# Epoch 71: loss improved from 0.00750 to 0.00632, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0089
# Epoch 72/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0322
# Epoch 72: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0171
# Epoch 73/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0014
# Epoch 73: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0110
# Epoch 74/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0066
# Epoch 74: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0087
# Epoch 75/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0132
# Epoch 75: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101
# Epoch 76/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0074
# Epoch 76: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072
# Epoch 77/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0102
# Epoch 77: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083
# Epoch 78/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0090
# Epoch 78: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0113
# Epoch 79/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0037
# Epoch 79: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049
# Epoch 80/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019
# Epoch 80: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0095
# Epoch 81/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0056
# Epoch 81: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0094
# Epoch 82/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0137
# Epoch 82: loss did not improve from 0.00632
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123
# Epoch 83/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0075
# Epoch 83: loss improved from 0.00632 to 0.00604, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0069
# Epoch 84/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0114
# Epoch 84: loss did not improve from 0.00604
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072
# Epoch 85/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0018
# Epoch 85: loss improved from 0.00604 to 0.00572, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0051
# Epoch 86/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0196
# Epoch 86: loss did not improve from 0.00572
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101
# Epoch 87/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0058
# Epoch 87: loss improved from 0.00572 to 0.00480, saving model to checkpoints_imports/best_model_imports.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0055
# Epoch 88/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0061
# Epoch 88: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055
# Epoch 89/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0096
# Epoch 89: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073
# Epoch 90/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0020
# Epoch 90: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057
# Epoch 91/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0023
# Epoch 91: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# Epoch 92/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0128
# Epoch 92: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0126
# Epoch 93/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0226
# Epoch 93: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0122
# Epoch 94/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0040
# Epoch 94: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072
# Epoch 95/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0122
# Epoch 95: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105
# Epoch 96/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0010
# Epoch 96: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0054
# Epoch 97/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0015
# Epoch 97: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044
# Epoch 98/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0038
# Epoch 98: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057
# Epoch 99/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0104
# Epoch 99: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0091
# Epoch 100/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 9.0488e-04
# Epoch 100: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035
# Epoch 101/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0034
# Epoch 101: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060
# Epoch 102/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0042
# Epoch 102: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0093
# Epoch 103/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0019
# Epoch 103: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0061
# Epoch 104/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0026
# Epoch 104: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065
# Epoch 105/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0024
# Epoch 105: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064
# Epoch 106/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0219
# Epoch 106: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0142
# Epoch 107/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0090
# Epoch 107: loss did not improve from 0.00480
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0088
# Epoch 1/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step - loss: 0.3011
# Epoch 1: loss improved from inf to 0.25769, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.2539
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1190
# Epoch 2: loss improved from 0.25769 to 0.09894, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1161
# Epoch 3/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.0824
# Epoch 3: loss improved from 0.09894 to 0.04361, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0487
# Epoch 4/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1731
# Epoch 4: loss did not improve from 0.04361
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1030
# Epoch 5/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0130
# Epoch 5: loss improved from 0.04361 to 0.04360, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0362
# Epoch 6/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0459
# Epoch 6: loss did not improve from 0.04360
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0455
# Epoch 7/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0286
# Epoch 7: loss improved from 0.04360 to 0.04116, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0365
# Epoch 8/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0499
# Epoch 8: loss did not improve from 0.04116
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0535
# Epoch 9/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1078
# Epoch 9: loss did not improve from 0.04116
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0623
# Epoch 10/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0176
# Epoch 10: loss improved from 0.04116 to 0.03757, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0330
# Epoch 11/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0345
# Epoch 11: loss improved from 0.03757 to 0.03641, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0333
# Epoch 12/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0209
# Epoch 12: loss did not improve from 0.03641
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0307
# Epoch 13/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0146
# Epoch 13: loss did not improve from 0.03641
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0314
# Epoch 14/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0251
# Epoch 14: loss improved from 0.03641 to 0.02873, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0265
# Epoch 15/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - loss: 0.0135
# Epoch 15: loss did not improve from 0.02873
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0271
# Epoch 16/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0161
# Epoch 16: loss improved from 0.02873 to 0.02536, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0217
# Epoch 17/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0648
# Epoch 17: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0404
# Epoch 18/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0418
# Epoch 18: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0353
# Epoch 19/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0586
# Epoch 19: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0367
# Epoch 20/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0186
# Epoch 20: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0364
# Epoch 21/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0271
# Epoch 21: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0297
# Epoch 22/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0119
# Epoch 22: loss did not improve from 0.02536
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0266
# Epoch 23/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0357
# Epoch 23: loss improved from 0.02536 to 0.02176, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0235
# Epoch 24/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0186
# Epoch 24: loss did not improve from 0.02176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0250
# Epoch 25/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0467
# Epoch 25: loss did not improve from 0.02176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0297
# Epoch 26/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0109
# Epoch 26: loss did not improve from 0.02176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0232
# Epoch 27/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0307
# Epoch 27: loss did not improve from 0.02176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0304
# Epoch 28/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0144
# Epoch 28: loss did not improve from 0.02176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0240
# Epoch 29/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0091
# Epoch 29: loss improved from 0.02176 to 0.02141, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0176
# Epoch 30/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0042
# Epoch 30: loss improved from 0.02141 to 0.01781, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0145
# Epoch 31/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0062
# Epoch 31: loss did not improve from 0.01781
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0157
# Epoch 32/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0244
# Epoch 32: loss did not improve from 0.01781
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0241
# Epoch 33/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0164
# Epoch 33: loss did not improve from 0.01781
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0241
# Epoch 34/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0183
# Epoch 34: loss improved from 0.01781 to 0.01605, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0159
# Epoch 35/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0382
# Epoch 35: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0248
# Epoch 36/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0376
# Epoch 36: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0297
# Epoch 37/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0173
# Epoch 37: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0213
# Epoch 38/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0610
# Epoch 38: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0370
# Epoch 39/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0563
# Epoch 39: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0376
# Epoch 40/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0218
# Epoch 40: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0393
# Epoch 41/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0113
# Epoch 41: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0227
# Epoch 42/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0315
# Epoch 42: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0265
# Epoch 43/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0083
# Epoch 43: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0171
# Epoch 44/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0197
# Epoch 44: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0192
# Epoch 45/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0043
# Epoch 45: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0170
# Epoch 46/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0236
# Epoch 46: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0208
# Epoch 47/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0339
# Epoch 47: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0250
# Epoch 48/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0368
# Epoch 48: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0263
# Epoch 49/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0031
# Epoch 49: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0137
# Epoch 50/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0068
# Epoch 50: loss did not improve from 0.01605
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0187
# Epoch 51/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0200
# Epoch 51: loss improved from 0.01605 to 0.01543, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0168
# Epoch 52/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0023
# Epoch 52: loss did not improve from 0.01543
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0352
# Epoch 53/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0083
# Epoch 53: loss did not improve from 0.01543
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0121
# Epoch 54/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0054
# Epoch 54: loss did not improve from 0.01543
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0205
# Epoch 55/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0074
# Epoch 55: loss did not improve from 0.01543
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0167
# Epoch 56/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0232
# Epoch 56: loss did not improve from 0.01543
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0222
# Epoch 57/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0086
# Epoch 57: loss improved from 0.01543 to 0.01465, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0132
# Epoch 58/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0224
# Epoch 58: loss improved from 0.01465 to 0.01184, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0137
# Epoch 59/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0329
# Epoch 59: loss did not improve from 0.01184
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0196
# Epoch 60/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0042
# Epoch 60: loss did not improve from 0.01184
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0152
# Epoch 61/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0042
# Epoch 61: loss did not improve from 0.01184
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0175
# Epoch 62/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0107
# Epoch 62: loss improved from 0.01184 to 0.01162, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0127
# Epoch 63/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0026
# Epoch 63: loss improved from 0.01162 to 0.01060, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074
# Epoch 64/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0071
# Epoch 64: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0104
# Epoch 65/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0051
# Epoch 65: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0191
# Epoch 66/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0308
# Epoch 66: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0203
# Epoch 67/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0068
# Epoch 67: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0182
# Epoch 68/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0061
# Epoch 68: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130
# Epoch 69/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0121
# Epoch 69: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149
# Epoch 70/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0049
# Epoch 70: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0188
# Epoch 71/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0052
# Epoch 71: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0111
# Epoch 72/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0025
# Epoch 72: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0110
# Epoch 73/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0080
# Epoch 73: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0106
# Epoch 74/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0079
# Epoch 74: loss did not improve from 0.01060
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0102
# Epoch 75/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0038
# Epoch 75: loss improved from 0.01060 to 0.00898, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0074
# Epoch 76/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0041
# Epoch 76: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0081
# Epoch 77/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0149
# Epoch 77: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0118
# Epoch 78/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0111
# Epoch 78: loss improved from 0.00898 to 0.00898, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0086
# Epoch 79/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0018
# Epoch 79: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0122
# Epoch 80/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0051
# Epoch 80: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0117
# Epoch 81/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0150
# Epoch 81: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0117
# Epoch 82/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0118
# Epoch 82: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0144
# Epoch 83/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0111
# Epoch 83: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0124
# Epoch 84/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0078
# Epoch 84: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107
# Epoch 85/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0126
# Epoch 85: loss did not improve from 0.00898
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0100
# Epoch 86/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0044
# Epoch 86: loss improved from 0.00898 to 0.00620, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0058
# Epoch 87/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 1s 202ms/step - loss: 0.0116
# Epoch 87: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0128
# Epoch 88/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0053
# Epoch 88: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0097
# Epoch 89/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0082
# Epoch 89: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0097
# Epoch 90/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0146
# Epoch 90: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0113
# Epoch 91/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0040
# Epoch 91: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081
# Epoch 92/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0151
# Epoch 92: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0113
# Epoch 93/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0137
# Epoch 93: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0161
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107
# Epoch 94: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0111
# Epoch 95/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0230
# Epoch 95: loss did not improve from 0.00620
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0147
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068
# Epoch 96: loss improved from 0.00620 to 0.00587, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0067
# Epoch 97/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0094
# Epoch 97: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0115
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068
# Epoch 98: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0072
# Epoch 99/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0018
# Epoch 99: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0046
# Epoch 100/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0057
# Epoch 100: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0071
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0078
# Epoch 101: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0076
# Epoch 102/200
# 5/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0058
# Epoch 102: loss did not improve from 0.00587
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0059
# Epoch 103/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0018
# Epoch 103: loss improved from 0.00587 to 0.00377, saving model to checkpoints_waste/best_model_waste.keras
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030
# Epoch 104/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0136
# Epoch 104: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0092
# Epoch 105/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0029
# Epoch 105: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064
# Epoch 106/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0126
# Epoch 106: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078
# Epoch 107/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0125
# Epoch 107: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108
# Epoch 108/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0022
# Epoch 108: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072
# Epoch 109/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0060
# Epoch 109: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0074
# Epoch 110/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0065
# Epoch 110: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 111/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0037
# Epoch 111: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049
# Epoch 112/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0075
# Epoch 112: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0069
# Epoch 113/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054
# Epoch 113: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065
# Epoch 114/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0048
# Epoch 114: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0074
# Epoch 115/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0048
# Epoch 115: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074
# Epoch 116/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0043
# Epoch 116: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063
# Epoch 117/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.0443e-04
# Epoch 117: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060
# Epoch 118: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0061
# Epoch 119/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0094
# Epoch 119: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0072
# Epoch 120/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0030
# Epoch 120: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050
# Epoch 121/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0034
# Epoch 121: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0076
# Epoch 122/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0033
# Epoch 122: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0073
# Epoch 123/200
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0073
# Epoch 123: loss did not improve from 0.00377
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0088

# %%
# Function to predict future values
def forecast_future(model, X_scaled, future_years, scaler_y):
    current_seq = X_scaled[-3:].copy()  # Start with last 3 years of data
    future_preds = []  # Store future predictions

    for _ in range(future_years):
        # Predict next year
        pred = model.predict(current_seq[np.newaxis, :, :])
        future_preds.append(pred[0, 0])

        # Update sequence (slide window forward)
        next_seq = np.vstack([current_seq[1:], current_seq[-1]])
        current_seq = next_seq

    # Inverse transform to original scale
    return scaler_y.inverse_transform(np.array(future_preds).reshape(-1, 1))

# Forecast next 3 years (2024-2026)
future_years = 3
future_preds_imports = forecast_future(best_model_imports, X_scaled, future_years, scaler_y_imports)
future_preds_waste = forecast_future(best_model_waste, X_scaled, future_years, scaler_y_waste)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d483791b6a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d483791b240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
# Years for forecast (2024-2026)
years_forecast = list(range(2024, 2024 + future_years))

# Combine actual and forecasted data
df_combined = pd.DataFrame({
    'Year': list(df['Year']) + years_forecast,
    'Imports (tons)': list(df['Imports (tons)']) + list(future_preds_imports.flatten()),
    'Textile Waste (tons)': list(df['Textile Waste (tons)']) + list(future_preds_waste.flatten()),
    'Data Type': ['Actual'] * len(df['Year']) + ['Forecasted'] * future_years
})

# Plot imports forecast
plt.figure(figsize=(14, 6))
for dtype, d in df_combined.groupby("Data Type"):
    plt.plot(
        d['Year'],
        d['Imports (tons)'],
        label=f"{dtype} Imports",
        marker='o' if dtype == "Actual" else 'x',  # Different markers
        linestyle='--' if dtype == "Forecasted" else '-'  # Different line styles
    )
plt.xlabel("Year")
plt.ylabel("Imports (tons)")
plt.title("Actual and Forecasted Imports (2000–2026)")
plt.xticks(ticks=range(df_combined['Year'].min(), df_combined['Year'].max() + 1), rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# Plot waste forecast (similar structure)
plt.figure(figsize=(14, 6))
for dtype, d in df_combined.groupby("Data Type"):
    plt.plot(
        d['Year'],
        d['Textile Waste (tons)'],
        label=f"{dtype} Waste",
        marker='o' if dtype == "Actual" else 'x',
        linestyle='--' if dtype == "Forecasted" else '-'
    )
plt.xlabel("Year")
plt.ylabel("Textile Waste (tons)")
plt.title("Actual and Forecasted Textile Waste (2000–2026)")
plt.xticks(ticks=range(df_combined['Year'].min(), df_combined['Year'].max() + 1), rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Define number of forecast years
future_years = 3
years_forecast = list(range(2024, 2024 + future_years))

# Combine actual and forecasted data
df_combined = pd.DataFrame({
    'Year': list(df['Year']) + years_forecast,
    'Imports (tons)': list(df['Imports (tons)']) + list(future_preds_imports.flatten()),
    'Textile Waste (tons)': list(df['Textile Waste (tons)']) + list(future_preds_waste.flatten()),
    'Data Type': ['Actual'] * len(df['Year']) + ['Forecasted'] * future_years
})

# Plot both imports and textile waste on the same graph
plt.figure(figsize=(14, 6))
for dtype, d in df_combined.groupby("Data Type"):
    plt.plot(
        d['Year'],
        d['Imports (tons)'],
        label=f"{dtype} Imports",
        marker='o' if dtype == "Actual" else 'x',
        linestyle='--' if dtype == "Forecasted" else '-'
    )
    plt.plot(
        d['Year'],
        d['Textile Waste (tons)'],
        label=f"{dtype} Textile Waste",
        marker='s' if dtype == "Actual" else '^',
        linestyle='--' if dtype == "Forecasted" else '-'
    )

plt.xlabel("Year")
plt.ylabel("Tons")
plt.title("Actual and Forecasted Imports and Textile Waste (2000–2026)")
plt.xticks(ticks=range(df_combined['Year'].min(), df_combined['Year'].max() + 1), rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, r2_score

def mean_absolute_percentage_error(y_true, y_pred):  # Define MAPE manually
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), 1e-10, None))) * 100

# ------------------------------
# 9. Evaluate Model Performance on Training Data
# ------------------------------
def evaluate_model(model, X_seq, y_true, scaler_y, label):
    y_pred = model.predict(X_seq)
    y_pred_inv = scaler_y.inverse_transform(y_pred)
    y_true_inv = scaler_y.inverse_transform(y_true)

    mae = mean_absolute_error(y_true_inv, y_pred_inv)
    mape = mean_absolute_percentage_error(y_true_inv, y_pred_inv)
    r2 = r2_score(y_true_inv, y_pred_inv)

    print(f"\nModel Metrics for {label}:")
    print(f"Mean Absolute Error (MAE): {mae:.2f}")
    print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
    print(f"R-squared (R²): {r2:.4f}")

# Evaluate both models
evaluate_model(best_model_imports, X_seq, y_seq_imports, scaler_y_imports, "Imports")
evaluate_model(best_model_waste, X_seq, y_seq_waste, scaler_y_waste, "Textile Waste")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
#
# Model Metrics for Imports:
# Mean Absolute Error (MAE): 631.07
# Mean Absolute Percentage Error (MAPE): 2.94%
# R-squared (R²): 0.9512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
#
# Model Metrics for Textile Waste:
# Mean Absolute Error (MAE): 218.07
# Mean Absolute Percentage Error (MAPE): 3.02%
# R-squared (R²): 0.9415

# %%
import matplotlib.pyplot as plt

# Plot actual imports
plt.figure(figsize=(14, 6))
plt.plot(
    df['Year'],
    df['Imports (tons)'],
    label="Actual Imports",
    marker='o',
    linestyle='-'
)
plt.xlabel("Year")
plt.ylabel("Imports (tons)")
plt.title("Actual Imports (2000–2023)")
plt.xticks(ticks=range(df['Year'].min(), df['Year'].max() + 1), rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Plot actual textile waste
plt.figure(figsize=(14, 6))
plt.plot(
    df['Year'],
    df['Textile Waste (tons)'],
    label="Actual Textile Waste",
    marker='o',
    linestyle='-'
)
plt.xlabel("Year")
plt.ylabel("Textile Waste (tons)")
plt.title("Actual Textile Waste (2000–2023)")
plt.xticks(ticks=range(df['Year'].min(), df['Year'].max() + 1), rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Define number of forecast years
future_years = 3
years_forecast = list(range(2024, 2024 + future_years))

# Combine actual and forecasted data
df_combined = pd.DataFrame({
    'Year': list(df['Year']) + years_forecast,
    'Imports (tons)': list(df['Imports (tons)']) + list(future_preds_imports.flatten()),
    'Textile Waste (tons)': list(df['Textile Waste (tons)']) + list(future_preds_waste.flatten()),
    'Data Type': ['Actual'] * len(df['Year']) + ['Forecasted'] * future_years
})

# Print forecasted figures for each year
print("Forecasted Textile Imports and Waste (2024–2026):\n")
forecast_data = df_combined[df_combined['Data Type'] == 'Forecasted'][['Year', 'Imports (tons)', 'Textile Waste (tons)']]
print(forecast_data.to_string(index=False))

# Plot both imports and textile waste on the same graph
plt.figure(figsize=(14, 6))
for dtype, d in df_combined.groupby("Data Type"):
    plt.plot(
        d['Year'],
        d['Imports (tons)'],
        label=f"{dtype} Imports",
        marker='o' if dtype == "Actual" else 'x',
        linestyle='--' if dtype == "Forecasted" else '-'
    )
    plt.plot(
        d['Year'],
        d['Textile Waste (tons)'],
        label=f"{dtype} Textile Waste",
        marker='s' if dtype == "Actual" else '^',
        linestyle='--' if dtype == "Forecasted" else '-'
    )

plt.xlabel("Year")
plt.ylabel("Tons")
plt.title("Actual and Forecasted Imports and Textile Waste (2000–2026)")
plt.xticks(ticks=range(df_combined['Year'].min(), df_combined['Year'].max() + 1), rotation=45)
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Forecasted Textile Imports and Waste (2024–2026):
#
#  Year  Imports (tons)  Textile Waste (tons)
#  2024    24116.896484           7887.663086
#  2025    23351.017578           7087.560059
#  2026    23521.896484           7954.471680
